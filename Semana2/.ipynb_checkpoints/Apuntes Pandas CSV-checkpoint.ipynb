# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# Primero abriremos el archivo de lluvias en el 2018 a ver qué tal xD

# %%
lluvia18=pd.read_csv('data/2018Lluv.csv', encoding='latin-1')
lluvia18
# Out:
#              LON        LAT ESTADO     CLAVE_SIH                       NOMBRE  \
# 0    -102.309722  21.895000    AGS         AGSAG         Aguascalientes, Ags.
# 1    -102.466944  22.188611    AGS         ANVAG  Cincuenta Aniversario, Ags.
# 2    -102.712222  21.849167    AGS      CALVILLO          Calvillo, Ags. SMN*
# 3    -102.676944  21.997500    AGS         CDRAG            La Codorniz, Ags.
# 4    -102.197222  22.007222    AGS         CHOAG           Cañada Honda, Ags.
# ...          ...        ...    ...           ...                          ...
# 1879  -98.842833  19.936722    HGO      ZAPOTLAN           Zapotlán de Juárez
# 1880  -99.352933  19.295445    MEX         ZARCO                    Ocoyoacac
# 1881 -101.227500  18.060556    GRO  ZIHUAQUIOCFE            Coyuca de Catalán
# 1882 -101.554889  17.645056    GRO   ZIHUATANEJO        Zihuatanejo de Azueta
# 1883  -99.390806  20.740222    HGO    ZIMAPANSMN                      Zimapán
#
#        ENE
# 0     25.8
# ...

# %%
lluvia18.index
# Out:
# RangeIndex(start=0, stop=1884, step=1)

# %%
lluvia18.columns
# Out:
# Index(['LON', 'LAT', 'ESTADO', 'CLAVE_SIH', 'NOMBRE', 'ENE'], dtype='object')

# %%
lluvia18.values
# Out:
# array([[-102.309722, 21.895, 'AGS', 'AGSAG', 'Aguascalientes, Ags.',
#         25.8],
#        [-102.466944, 22.188610999999998, 'AGS', 'ANVAG',
#         'Cincuenta Aniversario, Ags.', 58.6],
#        [-102.712222, 21.849167, 'AGS', 'CALVILLO', 'Calvillo, Ags. SMN*',
#         56.0],
#        ...,
#        [-101.2275, 18.060556, 'GRO', 'ZIHUAQUIOCFE', 'Coyuca de Catalán',
#         0.4],
#        [-101.55488890000001, 17.64505556, 'GRO', 'ZIHUATANEJO',
#         'Zihuatanejo de Azueta', 2.2],
#        [-99.39080556, 20.74022222, 'HGO', 'ZIMAPANSMN', 'Zimapán', 9.8]],
#       dtype=object)

# %%
lluvia18['ENE']
# Out:
# 0       25.8
# 1       58.6
# 2       56.0
# 3       50.0
# 4       17.2
#         ...
# 1879     4.4
# 1880    20.4
# 1881     0.4
# 1882     2.2
# 1883     9.8
# Name: ENE, Length: 1884, dtype: float64

# %%
lluvia19= pd.read_csv('data/2019Lluv.csv',encoding='latin-1')
lluvia19
# Out:
#              LON        LAT  EDO CLAVE_SIH                       NOMBRE    ENE
# 0    -102.309722  21.895000  AGS     AGSAG         Aguascalientes, Ags.   6.61
# 1    -102.466944  22.188611  AGS     ANVAG  Cincuenta Aniversario, Ags.  10.60
# 2    -102.184167  21.738611  AGS     BRTAG            San Bartolo, Ags.  10.50
# 3    -102.712222  21.849167  AGS  CALVILLO          Calvillo, Ags. SMN*  18.17
# 4    -102.676944  21.997500  AGS     CDRAG            La Codorniz, Ags.  16.70
# ...          ...        ...  ...       ...                          ...    ...
# 1236 -102.344167  23.288611  ZAC     VCOZC           Villa de Cos, Zac.   7.00
# 1237 -101.916944  22.520278  ZAC     VGOZC  Villa González Ortega, Zac.  32.32
# 1238 -101.715833  22.347500  ZAC     VHGZC          Villa Hidalgo, Zac.   9.70
# 1239 -103.337500  21.588889  ZAC     VILZC     José María Morelos, Zac.  15.20
# 1240 -102.576667  22.761389  ZAC     ZACZC              Zacatecas, Zac.  12.02
#
# [1241 rows x 6 columns]

# %% [markdown]
# Usamos append para unir diferentes tablas

# %%
lluvia18.append(lluvia19)
# Out:
#              LON        LAT ESTADO CLAVE_SIH                       NOMBRE  \
# 0    -102.309722  21.895000    AGS     AGSAG         Aguascalientes, Ags.
# 1    -102.466944  22.188611    AGS     ANVAG  Cincuenta Aniversario, Ags.
# 2    -102.712222  21.849167    AGS  CALVILLO          Calvillo, Ags. SMN*
# 3    -102.676944  21.997500    AGS     CDRAG            La Codorniz, Ags.
# 4    -102.197222  22.007222    AGS     CHOAG           Cañada Honda, Ags.
# ...          ...        ...    ...       ...                          ...
# 1236 -102.344167  23.288611    NaN     VCOZC           Villa de Cos, Zac.
# 1237 -101.916944  22.520278    NaN     VGOZC  Villa González Ortega, Zac.
# 1238 -101.715833  22.347500    NaN     VHGZC          Villa Hidalgo, Zac.
# 1239 -103.337500  21.588889    NaN     VILZC     José María Morelos, Zac.
# 1240 -102.576667  22.761389    NaN     ZACZC              Zacatecas, Zac.
#
#         ENE  EDO
# 0     25.80  NaN
# 1     58.60  NaN
# 2     56.00  NaN
# ...

# %%
lluvia19.T
# Out:
#                            0                            1     \
# LON                     -102.31                     -102.467
# LAT                      21.895                      22.1886
# EDO                         AGS                          AGS
# CLAVE_SIH                 AGSAG                        ANVAG
# NOMBRE     Aguascalientes, Ags.  Cincuenta Aniversario, Ags.
# ENE                        6.61                         10.6
#
#                         2                    3                  4     \
# LON                 -102.184             -102.712           -102.677
# LAT                  21.7386              21.8492            21.9975
# EDO                      AGS                  AGS                AGS
# CLAVE_SIH              BRTAG             CALVILLO              CDRAG
# NOMBRE     San Bartolo, Ags.  Calvillo, Ags. SMN*  La Codorniz, Ags.
# ENE                     10.5                18.17               16.7
#
# ...

# %%
#Vamos a sumar tablas, lo único que hace es sumar todos los valores correspondientes
#a cada columna y fila, ésto es útil si tenemos datos iguales o en partes, pero en ésta
#ejercicio, no es útil :c
lluvia19+lluvia18
# Out:
#           CLAVE_SIH  EDO    ENE ESTADO        LAT         LON  \
# 0        AGSAGAGSAG  NaN  32.41    NaN  43.790000 -204.619444
# 1        ANVAGANVAG  NaN  69.20    NaN  44.377222 -204.933888
# 2     BRTAGCALVILLO  NaN  66.50    NaN  43.587778 -204.896389
# 3     CALVILLOCDRAG  NaN  68.17    NaN  43.846667 -205.389166
# 4        CDRAGCHOAG  NaN  33.90    NaN  44.004722 -204.874166
# ...             ...  ...    ...    ...        ...         ...
# 1879            NaN  NaN    NaN    NaN        NaN         NaN
# 1880            NaN  NaN    NaN    NaN        NaN         NaN
# 1881            NaN  NaN    NaN    NaN        NaN         NaN
# 1882            NaN  NaN    NaN    NaN        NaN         NaN
# 1883            NaN  NaN    NaN    NaN        NaN         NaN
#
#                                                  NOMBRE
# 0              Aguascalientes, Ags.Aguascalientes, Ags.
# 1     Cincuenta Aniversario, Ags.Cincuenta Aniversar...
# ...

# %% [markdown]
# Podemos hacer un merge entre varias tablas, los cuales se se unirán con sus correspondientes datos, dejando de lado todo lo que se 'repite', el formato es:
#
# tabla3=pd.merge(tabla1,tabla2)
#
# xD
